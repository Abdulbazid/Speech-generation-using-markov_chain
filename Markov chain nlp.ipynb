# %% [markdown]
# # Markov Chain

# %%
data = "hello hello hell helli"

# %%
def generatetable(data, k=4):
    T = {}

    for i in range(len(data) - k):
        # Extract the current sequence of length k as X
        X = data[i:i+k]
        # Extract the next element as Y
        Y = data[i+k]

        # Check if X is already in the table
        if X not in T:
            T[X] = {}

        # Check if Y is already in the inner dictionary of X
        if Y not in T[X]:
            T[X][Y] = 1
        else:
            T[X][Y] += 1

    return T

# %%
T = generatetable(data)
T
# Out:
# {'hell': {'o': 2, ' ': 1, 'i': 1},
#  'ello': {' ': 2},
#  'llo ': {'h': 2},
#  'lo h': {'e': 2},
#  'o he': {'l': 2},
#  ' hel': {'l': 3},
#  'ell ': {'h': 1},
#  'll h': {'e': 1},
#  'l he': {'l': 1}}

# %%
def convertfreqtoprob(T):
    for kx in T.keys():
        s = sum(T[kx].values())
        for k in T[kx].keys():
            T[kx][k] = T[kx][k]/s
            
    return T

# %%
convertfreqtoprob(T)
# Out:
# {'hell': {'o': 0.5, ' ': 0.25, 'i': 0.25},
#  'ello': {' ': 1.0},
#  'llo ': {'h': 1.0},
#  'lo h': {'e': 1.0},
#  'o he': {'l': 1.0},
#  ' hel': {'l': 1.0},
#  'ell ': {'h': 1.0},
#  'll h': {'e': 1.0},
#  'l he': {'l': 1.0}}

# %%
text_path = "markoc"

# %%
def loadtext(filename):
    with open(filename,encoding = 'utf8') as f:
        return f.read().lower()

# %%
text = loadtext(text_path)

# %%
text
# Out:
# 'ladies and gentlemen, today, we gather here to talk about something important: the value of kindness. kindness is a simple, yet powerful, act that can make a big difference in our world.\n\nfirst, let\'s understand what kindness is. kindness is when we are nice and friendly to others. it means being considerate of people\'s feelings and treating them with respect. it\'s about helping those in need without expecting anything in return.\n\nwhy is kindness so important? well, it makes our world a better place. when we are kind to one another, we create a positive and harmonious environment. think about it - when someone shows you kindness, it makes you feel happy and appreciated. and when you show kindness to others, you can make them feel the same way.\n\nkindness is not limited to big gestures. it can be as simple as giving someone a smile, holding the door for them, or saying a friendly "hello." these small acts of kindness can brighten someone\'s day and create a ripple effect of positivity.\n\nmoreover, kindness can bridge gaps and bring people together. it doesn\'t matter where someone comes from or what they believe in; kindness is a universal language that everyone can understand and appreciate. it\'s a way to build connections and foster understanding among people from diverse backgrounds.\n\nteaching kindness is also crucial, especially to our younger generation. when we teach our children to be kind, we are shaping them into compassionate and empathetic individuals who will contribute positively to society. kindness is a lesson that can last a lifetime.\n\nin conclusion, kindness is a simple but incredibly valuable quality that we should all embrace in our lives. it\'s a force for good that can change the world, one small act at a time. so, let\'s remember to be kind to one another, spread positivity, and make our world a better place for everyone. thank you for listening.\n\nkindness not only benefits individuals but also has a broader impact on our communities and society as a whole. when communities are built on a foundation of kindness, they become safer and more supportive places to live. people are more likely to come together to help one another in times of need, making neighborhoods stronger and more resilient.\n\nmoreover, kindness in the workplace can lead to a more productive and harmonious environment. when colleagues treat each other with respect and empathy, it fosters teamwork, creativity, and a sense of belonging. it\'s also been shown that employees who experience kindness at work are generally happier and more motivated.\n\nkindness is closely linked to empathy, the ability to understand and share the feelings of others. when we practice kindness, we develop our empathy muscles, which helps us build better relationships. empathetic individuals are better equipped to resolve conflicts peacefully and communicate effectively, which can lead to healthier and more meaningful connections with friends and family.\n\nanother remarkable aspect of kindness is its impact on mental health. when we are kind to others, it releases feel-good hormones like oxytocin in our brains. this not only improves our mood but also reduces stress and anxiety. in essence, practicing kindness is a natural way to boost our own mental well-being.\n\nfurthermore, acts of kindness often inspire others to pay it forward. when someone experiences a random act of kindness, they are more likely to do something kind for someone else. this domino effect creates a chain reaction of positivity that can extend far beyond our initial actions.\n\nnow, let\'s talk about the importance of self-kindness. it\'s crucial to remember that being kind to ourselves is just as vital as being kind to others. we all make mistakes and face challenges, but self-compassion helps us navigate these difficulties with greater resilience. by treating ourselves with kindness and forgiveness, we can maintain a healthy sense of self-worth and well-being.\n\nin conclus ...

# %% [markdown]
# # train markov chain

# %%
def trainmarkov(text,k):
    
    T = generatetable(text)
    
    T = convertfreqtoprob(T)
    
    return T

# %%
model  = trainmarkov(text,4)

# %%
model
# Out:
# {'ladi': {'e': 1.0},
#  'adie': {'s': 1.0},
#  'dies': {' ': 1.0},
#  'ies ': {'a': 0.75, 'w': 0.25},
#  'es a': {'n': 0.5714285714285714,
#   'r': 0.14285714285714285,
#   ' ': 0.2857142857142857},
#  's an': {'d': 1.0},
#  ' and': {' ': 1.0},
#  'and ': {'g': 0.02702702702702703,
#   'w': 0.10810810810810811,
#   'f': 0.13513513513513514,
#   't': 0.05405405405405406,
#   'h': 0.05405405405405406,
#   'a': 0.16216216216216217,
#   'c': 0.05405405405405406,
#   'b': 0.02702702702702703,
#   'e': 0.05405405405405406,
#   'm': 0.16216216216216217,
#   's': 0.05405405405405406,
#   'o': 0.02702702702702703,
#   'i': 0.08108108108108109},
#  'nd g': {'e': 1.0},
#  'd ge': {'n': 1.0},
#  ' gen': {'t': 0.3333333333333333, 'e': 0.6666666666666666},
#  'gent': {'l': 1.0},
#  'entl': {'e': 1.0},
#  'ntle': {'m': 1.0},
#  'tlem': {'e': 1.0},
#  'leme': {'n': 1.0},
#  'emen': {',': 1.0},
#  'men,': {' ': 1.0},
#  'en, ': {'t': 1.0},
#  'n, t': {'o': 1.0},
#  ', to': {'d': 1.0},
#  ' tod': {'a': 1.0},
#  'toda': {'y': 1.0},
#  'oday': {',': 1.0},
#  'day,': {' ': 1.0},
#  'ay, ': {'w': 0.3333333333333333,
#   'b': 0.3333333333333333,
#   'a': 0.3333333333333333},
#  'y, w': {'e': 0.5, 'h': 0.5},
#  ', we': {' ': 1.0},
#  ' we ': {'g': 0.08333333333333333,
#   'a': 0.4166666666666667,
#   'c': 0.16666666666666666,
#   't': 0.08333333333333333,
#   's': 0.08333333333333333,
#   'p': 0.08333333333333333,
#   'd': 0.08333333333333333},
#  'we g': {'a': 1.0},
#  'e ga': {'t': 0.5, 'p': 0.5},
#  ' gat': {'h': 1.0},
#  'gath': {'e': 1.0},
#  'athe': {'r': 0.3333333333333333, 't': 0.6666666666666666},
#  'ther': {' ': 0.3333333333333333,
#   's': 0.4,
#   ',': 0.13333333333333333,
#   '.': 0.06666666666666667,
#   'm': 0.06666666666666667},
#  'her ': {'h': 0.2, 't': 0.2, 'i': 0.2, 'w': 0.2, 'r': 0.2},
#  'er h': {'e': 1.0},
#  'r he': {'r': 1.0},
#  ' her': {'e': 1.0},
#  'here': {' ': 1.0},
#  'ere ': {'t': 0.5, 's': 0.5},
#  're t': {'o': 0.5, 'h': 0.5},
#  'e to': {' ': 0.5, 'g': 0.5},
#  ' to ': {'t': 0.03571428571428571,
#   'o': 0.32142857142857145,
#   'b': 0.17857142857142858,
#   's': 0.03571428571428571,
#   'l': 0.03571428571428571,
#   'c': 0.03571428571428571,
#   'h': 0.10714285714285714,
#   'a': 0.03571428571428571,
#   'e': 0.03571428571428571,
#   'u': 0.03571428571428571,
#   'r': 0.07142857142857142,
#   'p': 0.03571428571428571,
#   'd': 0.03571428571428571},
#  'to t': {'a': 1.0},
#  'o ta': {'l': 1.0},
#  ' tal': {'k': 1.0},
#  'talk': {' ': 1.0},
#  'alk ': {'a': 1.0},
#  'lk a': {'b': 1.0},
#  'k ab': {'o': 1.0},
#  ' abo': {'u': 1.0},
#  'abou': {'t': 1.0},
#  'bout': {' ': 1.0},
#  'out ': {'s': 0.2, 'h': 0.2, 'e': 0.2, 'i': 0.2, 't': 0.2},
#  'ut s': {'o': 0.5, 'e': 0.5},
#  't so': {'m': 1.0},
#  ' som': {'e': 1.0},
#  'some': {'t': 0.25, 'o': 0.75},
#  'omet': {'h': 1.0},
#  'meth': {'i': 1.0},
#  'ethi': {'n': 1.0},
#  'thin': {'g': 0.75, 'k': 0.25},
#  'hing': {' ': 1.0},
#  'ing ': {'i': 0.1,
#   'c': 0.05,
#   't': 0.2,
#   'a': 0.15,
#   's': 0.05,
#   'p': 0.05,
#   'k': 0.25,
#   'n': 0.05,
#   'o': 0.05,
#   'h': 0.05},
#  'ng i': {'m': 0.5, 'n': 0.5},
#  'g im': {'p': 1.0},
#  ' imp': {'o': 0.5, 'a': 0.3333333333333333, 'r': 0.16666666666666666},
#  'impo': {'r': 1.0},
#  'mpor': {'t': 1.0},
#  'port': {'a': 0.75, 'i': 0.25},
#  'orta': {'n': 1.0},
#  'rtan': {'t': 0.6666666666666666, 'c': 0.3333333333333333},
#  'tant': {':': 0.5, '?': 0.5},
#  'ant:': {' ': 1.0},
#  'nt: ': {'t': 1.0},
#  't: t': {'h': 1.0},
#  ': th': {'e': 1.0},
#  ' the': {' ': 0.5263157894736842,
#   'm': 0.21052631578947367,
#   's': 0.10526315789473684,
#   'y': 0.15789473684210525},
#  'the ': {'v': 0.1,
#   's': 0.1,
#   'd': 0.1,
#   'w': 0.3,
#   'a': 0.1,
#   'f': 0.1,
#   'i': 0.1,
#   'p': 0.1},
#  'he v': {'a': 1.0},
#  'e va': {'l': 1.0},
#  ' val': {'u': 1.0},
#  'valu': {'e': 0.5, 'a': 0.5},
#  'alue': {' ': 1.0},
#  'lue ': {'o': 1.0},
#  'ue o': {'f': 1.0},
#  'e of': {' ': 1.0},
#  ' of ': {'k': 0.4,
#   'p': 0.2,
#   'n': 0.06666666666666667,
#   'b': 0.13333333333333333,
#   'o': 0.06666666666666667,
#   's': 0.13333333333333333},
#  'of k': {'i': 1.0},
#  'f ki': {'n': 1.0},
#  ' kin': {'d': 1.0},
#  'kind': {'n': 0.8055555555555556,
#   ' ': 0.16666666666666666,
#   ',': 0.027777777777777776},
#  'indn': {'e': 1.0},
#  'ndne': {'s': 1.0},
#  'dnes': {'s': 1.0},
#  'ness': {'.': 0.06666666666666667,
#   ' ': 0.7666666666666667,
#   ',': 0.16666666666666666},
#  'ess.': {' ': 1.0},
#  'ss. ': {'k': 0.5, 'i': 0.5},
#  's. k': {'i': 1.0},
#  '. ki': {'n': 1.0},
#  'ess ': {'i': 0.5416666666666666,
#   's': 0.041666666666666664,
#   't': 0.041666666666666664,
#   'c': 0.08333333333333333,
#   'n': 0.041666666666666664,
#   'a': 0.20833333333333334,
#   'o': 0.041666666666666664},
#  'ss i': {'s': 0.9230769230769231, 'n': 0.07692307692307693},
#  's is': {' ': 0.9230769230769231, '.': 0.07692307692307693},
#  ' is ': {'a': 0.5384615384615384,
#   'w': 0.07692307692307693,
#   'k': 0.07692307692307693,
#   'n': 0.07692307692307693,
#   'c': 0.07692307692307693,
#   'i': 0.07692307692307693,
#   'j': 0.07692307692307693},
#  'is a': {' ': 0.8571428571428571, 'l': 0.14285714285714285},
#  's a ': {'s': 0.21428571428571427,
#   'u': 0.07142857142857142,
#   'w': 0.14285714285714285,
#   'l': 0.07142857142857142,
#   'f': 0.14285714285714285,
#   'b': 0.07142857142857142,
#   'n': 0.07142857142857142,
#   'r': 0.07142857142857142,
#   'c': 0.07142857142857142,
#   'h': 0.07142857142857142},
#  ' a s': {'i': 0.6, 'm': 0.2, 'e': 0.2},
#  'a si': {'m': 1.0},
#  ' sim': {'p': 1.0},
#  'simp': {'l': 1.0},
#  'impl': {'e': 1.0},
#  'mple': {',': 0.25, ' ': 0.75},
#  'ple,': {' ': 1.0},
#  'le, ': {'y': 0.5, 'h': 0.5},
#  'e, y': {'e': 1.0},
#  ', ye': {'t': 1.0},
#  ' yet': {' ': 1.0},
#  'yet ': {'p': 1.0},
#  'et p': {'o': 0.5, 'r': 0.5},
#  't po': {'w': 1.0},
#  ' pow': {'e': 1.0},
#  'powe': {'r': 1.0},
#  'ower': {'f': 0.5, ' ': 0.5},
#  'werf': {'u': 1.0},
#  'erfu': {'l': 1.0},
#  'rful': {',': 1.0},
#  'ful,': {' ': 1.0},
#  'ul, ': {'a': 1.0},
#  'l, a': {'c': 1.0},
#  ', ac': {'t': 1.0},
#  ' act': {' ': 0.42857142857142855,
#   's': 0.2857142857142857,
#   'i': 0.2857142857142857},
#  'act ': {'t': 0.2, 'a': 0.2, 'o': 0.6},
#  'ct t': {'h': 1.0},
#  't th': {'a': 0.3333333333333333, 'e': 0.6666666666666666},
#  ' tha': {'t': 0.8181818181818182, 'n': 0.18181818181818182},
#  'that': {' ': 1.0},
#  'hat ': {'c': 0.45454545454545453,
#   'k': 0.09090909090909091,
#   't': 0.09090909090909091,
#   'e': 0.18181818181818182,
#   'w': 0.09090909090909091,
#   'b': 0.09090909090909091},
#  'at c': {'a': 1.0},
#  't ca': {'n': 1.0},
#  ' can': {' ': 1.0},
#  'can ': {'m': 0.23076923076923078,
#   'b': 0.23076923076923078,
#   'u': 0.07692307692307693,
#   'l': 0.23076923076923078,
#   'c': 0.07692307692307693,
#   'e': 0.07692307692307693,
#   't': 0.07692307692307693},
#  'an m': {'a': 1.0},
#  'n ma': {'k': 0.6666666666666666, 'i': 0.3333333333333333},
#  ' mak': {'e': 0.875, 'i': 0.125},
#  'make': {' ': 0.7142857142857143, 's': 0.2857142857142857},
#  'ake ': {'a': 0.2, 't': 0.2, 'o': 0.2, 'm': 0.2, 'k': 0.2},
#  'ke a': {' ': 1.0},
#  'e a ': {'b': 0.25, 'p': 0.25, 's': 0.25, 'r': 0.25},
#  ' a b': {'i': 0.25, 'e': 0.5, 'r': 0.25},
#  'a bi': {'g': 1.0},
#  ' big': {' ': 1.0},
#  'big ': {'d': 0.5, 'g': 0.5},
#  'ig d': {'i': 1.0},
#  'g di': {'f': 1.0},
#  ' dif': {'f': 1.0},
#  'diff': {'e': 0.5, 'i': 0.5},
#  'iffe': {'r': 1.0},
#  'ffer': {'e': 1.0},
#  'fere': {'n': 1.0},
#  'eren': {'c': 1.0},
#  'renc': {'e': 1.0},
#  'ence': {' ': 0.4, ',': 0.2, 's': 0.2, '.': 0.2},
#  'nce ': {'i': 0.3333333333333333,
#   'k': 0.3333333333333333,
#   'o': 0.3333333333333333},
#  'ce i': {'n': 1.0},
#  'e in': {' ': 0.75, ';': 0.25},
#  ' in ': {'o': 0.375, 'n': 0.125, 'r': 0.125, 't': 0.25, 'e': 0.125},
#  'in o': {'u': 1.0},
#  'n ou': {'r': 1.0},
#  ' our': {' ': 0.8421052631578947, 's': 0.15789473684210525},
#  'our ': {'w': 0.23529411764705882,
#   'y': 0.058823529411764705,
#   'c': 0.17647058823529413,
#   'l': 0.11764705882352941,
#   'e': 0.058823529411764705,
#   'b': 0.058823529411764705,
#   'm': 0.058823529411764705,
#   'o': 0.058823529411764705,
#   'i': 0.058823529411764705,
#   'a': 0.11764705882352941},
#  'ur w': {'o': 1.0},
#  'r wo': {'r': 1.0},
#  ' wor': {'l': 0.75, 'k': 0.25},
#  'worl': {'d': 1.0},
#  'orld': {'.': 0.3333333333333333, ' ': 0.5, ',': 0.16666666666666666},
#  'rld.': {'\n': 0.5, ' ': 0.5},
#  'ld.\n': {'\n': 1.0},
#  'd.\n\n': {'f': 0.5, 'k': 0.5},
#  '.\n\nf': {'i': 0.5, 'u': 0.5},
#  '\n\nfi': {'r': 1.0},
#  '\nfir': {'s': 1.0},
#  'firs': {'t': 1.0},
#  'irst': {',': 1.0},
#  'rst,': {' ': 1.0},
#  'st, ': {'l': 1.0},
#  't, l': {'e': 1.0},
#  ', le': {'t': 1.0},
#  ' let': {"'": 1.0},
#  "let'": {'s': 1.0},
#  "et's": {' ': 1.0},
#  "t's ": {'u': 0.1, 'a': 0.5, 'r': 0.1, 't': 0.1, 'c': 0.1, 'm': 0.1},
#  "'s u": {'n': 1.0},
#  's un': {'d': 1.0},
#  ' und': {'e': 1.0},
#  'unde': {'r': 1.0},
#  'nder': {'s': 1.0},
#  'ders': {'t': 1.0},
#  'erst': {'a': 1.0},
#  'rsta': {'n': 1.0},
#  'stan': {'d': 1.0},
#  'tand': {' ': 0.75, 'i': 0.25},
#  'nd w': {'h': 0.5, 'e': 0.25, 'a': 0.25},
#  'd wh': {'a': 0.5, 'e': 0.5},
#  ' wha': {'t': 1.0},
#  'what': {' ': 1.0},
#  'at k': {'i': 1.0},
#  't ki': {'n': 1.0},
#  ' is.': {' ': 1.0},
#  'is. ': {'k': 1.0},
#  'is w': {'h': 1.0},
#  's wh': {'e': 0.3333333333333333, 'o': 0.6666666666666666},
#  ' whe': {'n': 0.9090909090909091, 'r': 0.09090909090909091},
#  'when': {' ': 1.0},
#  'hen ': {'w': 0.5, 's': 0.2, 'y': 0.1, 'c': 0.2},
#  'en w': {'e': 1.0},
#  'n we': {' ': 1.0},
#  'we a': {'r': 0.8, 'l': 0.2},
#  'e ar': {'e': 1.0},
#  ' are': {' ': 1.0},
#  'are ': {'n': 0.1,
#   'k': 0.2,
#   's': 0.1,
#   'b': 0.2,
#   'm': 0.2,
#   'g': 0.1,
#   't': 0.1},
#  're n': {'i': 1.0},
#  'e ni': {'c': 1.0},
#  ' nic': {'e': 1.0},
#  'nice': {' ': 1.0},
#  'ice ': {'a': 0.5, 'k': 0.5},
#  'ce a': {'n': 1.0},
#  'e an': {'d': 0.5714285714285714, 'o': 0.42857142857142855},
#  'nd f': {'r': 0.125, 'o': 0.5, 'a': 0.375},
#  'd fr': {'i': 1.0},
#  ' fri': {'e': 1.0},
#  'frie': {'n': 1.0},
#  'rien': {'d': 0.6, 'c': 0.4},
#  'iend': {'l': 0.6666666666666666, 's': 0.3333333333333333},
#  'endl': {'y': 1.0},
#  'ndly': {' ': 1.0},
#  'dly ': {'t': 0.5, '"': 0.5},
#  'ly t': {'o': 1.0},
#  'y to': {' ': 1.0},
#  'to o': {'t': 0.4444444444444444,
#   'n': 0.2222222222222222,
#   'u': 0.3333333333333333},
#  'o ot': {'h': 1.0},
#  ' oth': {'e': 1.0},
#  'othe': {'r': 1.0},
#  'hers': {'.': 0.5, ',': 0.3333333333333333, ' ': 0.16666666666666666},
#  'ers.': {' ': 1.0},
#  'rs. ': {'i': 0.3333333333333333, 'w': 0.6666666666666666},
#  's. i': {'t': 1.0},
#  '. it': {' ': 0.3333333333333333, "'": 0.6666666666666666},
#  ' it ': {'m': 0.2727272727272727,
#   '-': 0.09090909090909091,
#   'c': 0.09090909090909091,
#   'd': 0.09090909090909091,
#   'f': 0.18181818181818182,
#   'r': 0.09090909090909091,
#   'h': 0.09090909090909091,
#   'b': 0.09090909090909091},
#  'it m': {'e': 0.3333333333333333, 'a': 0.6666666666666666},
#  't me': {'a': 1.0},
#  ' mea': {'n': 1.0},
#  'mean': {'s': 0.5, 'i': 0.5},
#  'eans': {' ': 1.0},
#  'ans ': {'b': 1.0},
#  'ns b': {'e': 1.0},
#  's be': {'i': 1.0},
#  ' bei': {'n': 1.0},
#  'bein': {'g': 1.0},
#  'eing': {' ': 0.6666666666666666, '.': 0.3333333333333333},
#  'ng c': {'o': 1.0},
#  'g co': {'n': 1.0},
#  ' con': {'s': 0.125, 'n': 0.375, 't': 0.125, 'c': 0.25, 'f': 0.125},
#  'cons': {'i': 1.0},
#  'onsi': {'d': 1.0},
#  'nsid': {'e': 1.0},
#  'side': {'r': 1.0},
#  'ider': {'a': 1.0},
#  'dera': {'t': 1.0},
#  'erat': {'e': 0.5, 'i': 0.5},
#  'rate': {' ': 1.0},
#  'ate ': {'o': 0.16666666666666666,
#   'a': 0.5,
#   'e': 0.16666666666666666,
#   't': 0.16666666666666666},
#  'te o': {'f': 1.0},
#  'of p': {'e': 0.3333333333333333, 'o': 0.6666666666666666},
#  'f pe': {'o': 1.0},
#  ' peo': {'p': 1.0},
#  'peop': {'l': 1.0},
#  'eopl': {'e': 1.0},
#  'ople': {"'": 0.25, ' ': 0.75},
#  "ple'": {'s': 1.0},
#  "le's": {' ': 1.0},
#  "e's ": {'f': 0.5, 'd': 0.5},
#  "'s f": {'e': 1.0},
#  's fe': {'e': 1.0},
#  ' fee': {'l': 1.0},
#  'feel': {'i': 0.4, ' ': 0.4, '-': 0.2},
#  'eeli': {'n': 1.0},
#  'elin': {'g': 1.0},
#  'ling': {'s': 1.0},
#  'ings': {' ': 1.0},
#  'ngs ': {'a': 0.3333333333333333,
#   'o': 0.3333333333333333,
#   'p': 0.3333333333333333},
#  'gs a': {'n': 1.0},
#  'nd t': {'r': 0.14285714285714285,
#   'o': 0.7142857142857143,
#   'h': 0.14285714285714285},
#  'd tr': {'e': 1.0},
#  ' tre': {'a': 1.0},
#  'trea': {'t': 1.0},
#  'reat': {'i': 0.375, 'e': 0.5, ' ': 0.125},
#  'eati': {'n': 0.6666666666666666, 'v': 0.3333333333333333},
#  'atin': {'g': 1.0},
#  'ting': {' ': 1.0},
#  'ng t': {'h': 1.0},
#  'g th': {'e': 0.75, 'o': 0.25},
#  'them': {' ': 0.75, ',': 0.25},
#  'hem ': {'w': 0.3333333333333333,
#   'f': 0.3333333333333333,
#   'i': 0.3333333333333333},
#  'em w': {'i': 1.0},
#  'm wi': {'t': 1.0},
#  ' wit': {'h': 1.0},
#  'with': {' ': 0.8333333333333334, 'o': 0.16666666666666666},
#  'ith ': {'r': 0.4, 'f': 0.2, 'g': 0.2, 'k': 0.2},
#  'th r': {'e': 1.0},
#  'h re': {'s': 1.0},
#  ' res': {'p': 0.4, 'i': 0.4, 'o': 0.2},
#  'resp': {'e': 1.0},
#  'espe': {'c': 1.0},
#  'spec': {'t': 0.8, 'i': 0.2},
#  'pect': {'.': 0.2, 'i': 0.2, ' ': 0.6},
#  'ect.': {' ': 1.0},
#  'ct. ': {'i': 1.0},
#  't. i': {'t': 1.0},
#  " it'": {'s': 1.0},
#  "it's": {' ': 1.0},
#  "'s a": {'b': 0.2, ' ': 0.6, 'l': 0.2},
#  's ab': {'o': 1.0},
#  'ut h': {'e': 1.0},
#  't he': {'l': 1.0},
#  ' hel': {'p': 1.0},
#  'help': {'i': 0.25, ' ': 0.25, 's': 0.5},
#  'elpi': {'n': 1.0},
#  'lpin': {'g': 1.0},
#  'ping': {' ': 1.0},
#  ' tho': {'s': 1.0},
#  'thos': {'e': 1.0},
#  'hose': {' ': 1.0},
#  'ose ': {'i': 1.0},
#  'se i': {'n': 1.0},
#  'in n': {'e': 1.0},
#  'n ne': {'e': 1.0},
#  ' nee': {'d': 1.0},
#  'need': {' ': 0.5, ',': 0.5},
#  'eed ': {'w': 1.0},
#  'ed w': {'i': 1.0},
#  'd wi': {'t': 1.0},
#  'itho': {'u': 1.0},
#  'thou': {'t': 1.0},
#  'hout': {' ': 1.0},
#  'ut e': {'x': 0.5, 'v': 0.5},
#  't ex': {'p': 1.0},
#  ' exp': {'e': 1.0},
#  'expe': {'c': 0.3333333333333333, 'r': 0.6666666666666666},
#  'xpec': {'t': 1.0},
#  'ecti': {'n': 0.25, 'o': 0.5, 'v': 0.25},
#  'ctin': {'g': 1.0},
#  'ng a': {'n': 0.3333333333333333,
#   ' ': 0.3333333333333333,
#   'm': 0.3333333333333333},
#  'g an': {'y': 1.0},
#  ' any': {'t': 1.0},
#  'anyt': {'h': 1.0},
#  'nyth': {'i': 1.0},
#  'ythi': {'n': 1.0},
#  'g in': {' ': 1.0},
#  'in r': {'e': 1.0},
#  'n re': {'t': 0.5, 'a': 0.5},
#  ' ret': {'u': 1.0},
#  'retu': {'r': 1.0},
#  'etur': {'n': 1.0},
#  'turn': {'.': 1.0},
#  'urn.': {'\n': 1.0},
#  'rn.\n': {'\n': 1.0},
#  'n.\n\n': {'w': 1.0},
#  '.\n\nw': {'h': 1.0},
#  '\n\nwh': {'y': 1.0},
#  '\nwhy': {' ': 1.0},
#  'why ': {'i': 1.0},
#  'hy i': {'s': 1.0},
#  'y is': {' ': 1.0},
#  'is k': {'i': 1.0},
#  's ki': {'n': 1.0},
#  'ss s': {'o': 1.0},
#  's so': {' ': 1.0},
#  ' so ': {'i': 1.0},
#  'so i': {'m': 1.0},
#  'o im': {'p': 1.0},
#  'ant?': {' ': 1.0},
#  'nt? ': {'w': 1.0},
#  't? w': {'e': 1.0},
#  '? we': {'l': 1.0},
#  ' wel': {'l': 1.0},
#  'well': {',': 0.3333333333333333, '-': 0.6666666666666666},
#  'ell,': {' ': 1.0},
#  'll, ': {'i': 1.0},
#  'l, i': {'t': 1.0},
#  ', it': {' ': 1.0},
#  't ma': {'k': 0.6666666666666666, 't': 0.3333333333333333},
#  'akes': {' ': 1.0},
#  'kes ': {'o': 0.3333333333333333,
#   'y': 0.3333333333333333,
#   'a': 0.3333333333333333},
#  'es o': {'u': 0.6666666666666666, 'f': 0.3333333333333333},
#  's ou': {'r': 1.0},
#  'rld ': {'a': 1.0},
#  'ld a': {' ': 0.5, 'l': 0.25, 'r': 0.25},
#  'd a ': {'b': 0.6666666666666666, 's': 0.3333333333333333},
#  'a be': {'t': 1.0},
#  ' bet': {'t': 1.0},
#  'bett': {'e': 1.0},
#  'ette': {'r': 1.0},
#  'tter': {' ': 1.0},
#  'ter ': {'p': 0.2857142857142857,
#   'w': 0.14285714285714285,
#   'u': 0.14285714285714285,
#   'r': 0.2857142857142857,
#   'e': 0.14285714285714285},
#  'er p': {'l': 1.0},
#  'r pl': {'a': 1.0},
#  ' pla': {'c': 1.0},
#  'plac': {'e': 1.0},
#  'lace': {'.': 0.25, ' ': 0.5, 's': 0.25},
#  'ace.': {' ': 1.0},
#  'ce. ': {'w': 0.5, 'b': 0.5},
#  'e. w': {'h': 1.0},
#  '. wh': {'e': 1.0},
#  're k': {'i': 1.0},
#  'e ki': {'n': 1.0},
#  'ind ': {'t': 0.8333333333333334, 'f': 0.16666666666666666},
#  'd to': {' ': 1.0},
#  'o on': {'e': 1.0},
#  ' one': {' ': 1.0},
#  'one ': {'a': 0.4, 's': 0.2, 'c': 0.2, 'e': 0.2},
#  'ne a': {'n': 0.75, ' ': 0.25},
#  ' ano': {'t': 1.0},
#  'anot': {'h': 1.0},
#  'noth': {'e': 1.0},
#  'her,': {' ': 1.0},
#  'er, ': {'w': 0.25, 'k': 0.5, 's': 0.25},
#  'r, w': {'e': 1.0},
#  'we c': {'r': 0.5, 'a': 0.5},
#  'e cr': {'e': 1.0},
#  ' cre': {'a': 1.0},
#  'crea': {'t': 1.0},
#  'eate': {' ': 0.5, 's': 0.25, 'r': 0.25},
#  'te a': {' ': 0.6666666666666666, 'n': 0.3333333333333333},
#  ' a p': {'o': 1.0},
#  'a po': {'s': 1.0},
#  ' pos': {'i': 1.0},
#  'posi': {'t': 1.0},
#  'osit': {'i': 1.0},
#  'siti': {'v': 1.0},
#  'itiv': {'e': 0.5, 'i': 0.5},
#  'tive': {' ': 0.6666666666666666, 'l': 0.3333333333333333},
#  'ive ': {'a': 0.5, 'p': 0.25, 'c': 0.25},
#  've a': {'n': 1.0},
#  'nd h': {'a': 1.0},
#  'd ha': {'r': 1.0},
#  ' har': {'m': 1.0},
#  'harm': {'o': 1.0},
#  'armo': {'n': 1.0},
#  'rmon': {'i': 0.6666666666666666, 'e': 0.3333333333333333},
#  'moni': {'o': 1.0},
#  'onio': {'u': 1.0},
#  'niou': {'s': 1.0},
#  'ious': {' ': 1.0},
#  'ous ': {'e': 1.0},
#  'us e': {'n': 1.0},
#  's en': {'v': 1.0},
#  ' env': {'i': 1.0},
#  'envi': {'r': 1.0},
#  'nvir': {'o': 1.0},
#  'viro': {'n': 1.0},
#  'iron': {'m': 1.0},
#  'ronm': {'e': 1.0},
#  'onme': {'n': 1.0},
#  'nmen': {'t': 1.0},
#  'ment': {'.': 0.4, 'a': 0.6},
#  'ent.': {' ': 0.6666666666666666, '\n': 0.3333333333333333},
#  'nt. ': {'t': 0.5, 'w': 0.5},
#  't. t': {'h': 1.0},
#  '. th': {'i': 0.6, 'a': 0.4},
#  ' thi': {'n': 0.3333333333333333, 's': 0.6666666666666666},
#  'hink': {' ': 1.0},
#  'ink ': {'a': 1.0},
#  'nk a': {'b': 1.0},
#  'ut i': {'t': 0.5, 'n': 0.5},
#  't it': {' ': 1.0},
#  'it -': {' ': 1.0},
#  't - ': {'w': 1.0},
#  ' - w': {'h': 1.0},
#  '- wh': {'e': 1.0},
#  'en s': {'o': 0.75, 'h': 0.25},
#  'n so': {'m': 1.0},
#  'omeo': {'n': 1.0},
#  'meon': {'e': 1.0},
#  'eone': {' ': 0.8333333333333334, "'": 0.16666666666666666},
#  'ne s': {'h': 0.5, 'm': 0.5},
#  'e sh': {'o': 0.6666666666666666, 'a': 0.3333333333333333},
#  ' sho': {'w': 0.75, 'u': 0.25},
#  'show': {'s': 0.3333333333333333,
#   ' ': 0.3333333333333333,
#   'n': 0.3333333333333333},
#  'hows': {' ': 1.0},
#  'ows ': {'y': 1.0},
#  'ws y': {'o': 1.0},
#  's yo': {'u': 1.0},
#  ' you': {' ': 0.75, 'n': 0.125, 'r': 0.125},
#  'you ': {'k': 0.16666666666666666,
#   'f': 0.5,
#   's': 0.16666666666666666,
#   'c': 0.16666666666666666},
#  'ou k': {'i': 1.0},
#  'u ki': {'n': 1.0},
#  'ess,': {' ': 1.0},
#  'ss, ': {'i': 0.2, 't': 0.4, 'w': 0.4},
#  's, i': {'t': 1.0},
#  'es y': {'o': 1.0},
#  'ou f': {'e': 0.3333333333333333, 'o': 0.6666666666666666},
#  'u fe': {'e': 1.0},
#  'eel ': {'h': 0.5, 't': 0.5},
#  'el h': {'a': 1.0},
#  'l ha': {'p': 1.0},
#  ' hap': {'p': 1.0},
#  'happ': {'y': 0.5, 'i': 0.5},
#  'appy': {' ': 1.0},
#  'ppy ': {'a': 1.0},
#  'py a': {'n': 1.0},
#  'y an': {'d': 1.0},
#  'nd a': {'p': 0.3333333333333333, 'n': 0.5, ' ': 0.16666666666666666},
#  'd ap': {'p': 1.0},
#  ' app': {'r': 1.0},
#  'appr': {'e': 1.0},
#  'ppre': {'c': 1.0},
#  'prec': {'i': 1.0},
#  'reci': {'a': 1.0},
#  'ecia': {'t': 0.6666666666666666, 'l': 0.3333333333333333},
#  'ciat': {'e': 1.0},
#  'iate': {'d': 0.5, '.': 0.5},
#  'ated': {'.': 1.0},
#  'ted.': {' ': 0.5, '\n': 0.5},
#  'ed. ': {'a': 1.0},
#  'd. a': {'n': 1.0},
#  '. an': {'d': 1.0},
#  'en y': {'o': 1.0},
#  'n yo': {'u': 1.0},
#  'ou s': {'h': 1.0},
#  'u sh': {'o': 1.0},
#  'how ': {'k': 1.0},
#  'ow k': {'i': 1.0},
#  'w ki': {'n': 1.0},
#  'ss t': {'o': 1.0},
#  's to': {' ': 1.0},
#  'ers,': {' ': 1.0},
#  'rs, ': {'y': 0.5, 'i': 0.5},
#  's, y': {'o': 1.0},
#  ', yo': {'u': 1.0},
#  'ou c': {'a': 1.0},
#  'u ca': {'n': 1.0},
#  'ke t': {'h': 1.0},
#  'e th': {'e': 0.6666666666666666, 'a': 0.3333333333333333},
#  'em f': {'e': 1.0},
#  'm fe': {'e': 1.0},
#  'el t': {'h': 1.0},
#  'l th': {'e': 1.0},
#  'he s': {'a': 1.0},
#  'e sa': {'m': 0.5, 'f': 0.5},
#  ' sam': {'e': 1.0},
#  'same': {' ': 1.0},
#  'ame ': {'w': 1.0},
#  'me w': {'a': 1.0},
#  'e wa': {'y': 1.0},
#  ' way': {'.': 0.3333333333333333, ' ': 0.6666666666666666},
#  'way.': {'\n': 1.0},
#  'ay.\n': {'\n': 1.0},
#  'y.\n\n': {'k': 0.3333333333333333,
#   'm': 0.3333333333333333,
#   'a': 0.3333333333333333},
#  '.\n\nk': {'i': 1.0},
#  '\n\nki': {'n': 1.0},
#  '\nkin': {'d': 1.0},
#  'is n': {'o': 1.0},
#  's no': {'t': 1.0},
#  ' not': {' ': 1.0},
#  'not ': {'l': 0.25, 'o': 0.5, 'j': 0.25},
#  'ot l': {'i': 1.0},
#  't li': {'m': 1.0},
#  ' lim': {'i': 1.0},
#  'limi': {'t': 1.0},
#  'imit': {'e': 1.0},
#  'mite': {'d': 1.0},
#  'ited': {' ': 1.0},
#  'ted ': {'t': 1.0},
#  'ed t': {'o': 1.0},
#  'to b': {'i': 0.2, 'u': 0.2, 'e': 0.4, 'o': 0.2},
#  'o bi': {'g': 1.0},
#  'ig g': {'e': 1.0},
#  'g ge': {'s': 1.0},
#  ' ges': {'t': 1.0},
#  'gest': {'u': 1.0},
#  'estu': {'r': 1.0},
#  'stur': {'e': 1.0},
#  'ture': {'s': 1.0},
#  'ures': {'.': 1.0},
#  'res.': {' ': 1.0},
#  'es. ': {'i': 1.0},
#  'it c': {'a': 1.0},
#  'an b': {'e': 0.3333333333333333, 'r': 0.6666666666666666},
#  'n be': {' ': 1.0},
#  ' be ': {'a': 0.3333333333333333, 'k': 0.6666666666666666},
#  'be a': {'s': 1.0},
#  'e as': {' ': 0.6666666666666666, 'p': 0.3333333333333333},
#  ' as ': {'s': 0.16666666666666666,
#   'g': 0.16666666666666666,
#   'a': 0.16666666666666666,
#   'v': 0.16666666666666666,
#   'b': 0.16666666666666666,
#   'i': 0.16666666666666666},
#  'as s': {'i': 1.0},
#  's si': {'m': 1.0},
#  'ple ': {'a': 0.2857142857142857,
#   'e': 0.14285714285714285,
#   't': 0.14285714285714285,
#   'f': 0.14285714285714285,
#   'b': 0.14285714285714285,
#   'y': 0.14285714285714285},
#  'le a': {'s': 0.6666666666666666, 'r': 0.3333333333333333},
#  'as g': {'i': 1.0},
#  's gi': {'v': 1.0},
#  ' giv': {'i': 1.0},
#  'givi': {'n': 1.0},
#  'ivin': {'g': 1.0},
#  'ving': {' ': 1.0},
#  'ng s': {'o': 1.0},
#  'g so': {'m': 1.0},
#  'a sm': {'i': 1.0},
#  ' smi': {'l': 1.0},
#  'smil': {'e': 1.0},
#  'mile': {',': 1.0},
#  'ile,': {' ': 1.0},
#  'e, h': {'o': 1.0},
#  ', ho': {'l': 1.0},
#  ' hol': {'d': 1.0},
#  'hold': {'i': 1.0},
#  'oldi': {'n': 1.0},
#  'ldin': {'g': 1.0},
#  'ding': {' ': 1.0},
#  'he d': {'o': 1.0},
#  'e do': {'o': 1.0},
#  ' doo': {'r': 1.0},
#  'door': {' ': 1.0},
#  'oor ': {'f': 1.0},
#  'or f': {'o': 1.0},
#  'r fo': {'r': 1.0},
#  ' for': {' ': 0.6, 'c': 0.2, 'w': 0.1, 'g': 0.1},
#  'for ': {'t': 0.16666666666666666,
#   'g': 0.16666666666666666,
#   'e': 0.16666666666666666,
#   'l': 0.16666666666666666,
#   's': 0.16666666666666666,
#   'y': 0.16666666666666666},
#  'or t': {'h': 1.0},
#  'r th': {'e': 0.5, 'a': 0.5},
#  'hem,': {' ': 1.0},
#  'em, ': {'o': 1.0},
#  'm, o': {'r': 1.0},
#  ', or': {' ': 1.0},
#  ' or ': {'s': 0.5, 'w': 0.5},
#  'or s': {'a': 0.5, 'o': 0.5},
#  'r sa': {'y': 1.0},
#  ' say': {'i': 1.0},
#  'sayi': {'n': 1.0},
#  'ayin': {'g': 1.0},
#  'ying': {' ': 1.0},
#  'g a ': {'f': 1.0},
#  ' a f': {'r': 0.25, 'o': 0.5, 'u': 0.25},
#  'a fr': {'i': 1.0},
#  'ly "': {'h': 1.0},
#  'y "h': {'e': 1.0},
#  ' "he': {'l': 1.0},
#  '"hel': {'l': 1.0},
#  'hell': {'o': 1.0},
#  'ello': {'.': 1.0},
#  'llo.': {'"': 1.0},
#  'lo."': {' ': 1.0},
#  'o." ': {'t': 1.0},
#  '." t': {'h': 1.0},
#  '" th': {'e': 1.0},
#  'thes': {'e': 1.0},
#  'hese': {' ': 1.0},
#  'ese ': {'s': 0.5, 'd': 0.5},
#  'se s': {'m': 1.0},
#  'e sm': {'a': 1.0},
#  ' sma': {'l': 1.0},
#  'smal': {'l': 1.0},
#  'mall': {' ': 1.0},
#  'all ': {'a': 0.5, 'e': 0.25, 'm': 0.25},
#  'll a': {'c': 1.0},
#  'l ac': {'t': 1.0},
#  'acts': {' ': 1.0},
#  'cts ': {'o': 0.6666666666666666, 'p': 0.3333333333333333},
#  'ts o': {'f': 1.0},
#  's of': {' ': 0.8, 't': 0.2},
#  'ss c': {'a': 1.0},
#  's ca': {'n': 1.0},
#  'n br': {'i': 1.0},
#  ' bri': {'g': 0.25, 'd': 0.25, 'n': 0.5},
#  'brig': {'h': 1.0},
#  'righ': {'t': 1.0},
#  'ight': {'e': 1.0},
#  'ghte': {'n': 1.0},
#  'hten': {' ': 1.0},
#  'ten ': {'s': 0.5, 'i': 0.5},
#  "one'": {'s': 1.0},
#  "ne's": {' ': 1.0},
#  "'s d": {'a': 1.0},
#  's da': {'y': 1.0},
#  ' day': {' ': 0.5, ',': 0.5},
#  'day ': {'a': 1.0},
#  'ay a': {'n': 1.0},
#  'nd c': {'r': 0.5, 'o': 0.5},
#  'd cr': {'e': 1.0},
#  ' a r': {'i': 0.5, 'a': 0.5},
#  'a ri': {'p': 1.0},
#  ' rip': {'p': 1.0},
#  'ripp': {'l': 1.0},
#  'ippl': {'e': 1.0},
#  'pple': {' ': 1.0},
#  'le e': {'f': 1.0},
#  'e ef': {'f': 1.0},
#  ' eff': {'e': 1.0},
#  'effe': {'c': 1.0},
#  'ffec': {'t': 1.0},
#  'fect': {' ': 0.6666666666666666, 'i': 0.3333333333333333},
#  'ect ': {'o': 0.6, 'a': 0.2, 'c': 0.2},
#  'ct o': {'f': 0.6666666666666666, 'n': 0.3333333333333333},
#  't of': {' ': 1.0},
#  'f po': {'s': 1.0},
#  'tivi': {'t': 1.0},
#  'ivit': {'y': 1.0},
#  'vity': {'.': 0.25, ',': 0.5, ' ': 0.25},
#  'ity.': {'\n': 1.0},
#  'ty.\n': {'\n': 1.0},
#  '.\n\nm': {'o': 1.0},
#  '\n\nmo': {'r': 1.0},
#  '\nmor': {'e': 1.0},
#  'more': {'o': 0.2, ' ': 0.7, ',': 0.1},
#  'oreo': {'v': 1.0},
#  'reov': {'e': 1.0},
#  'eove': {'r': 1.0},
#  'over': {',': 1.0},
#  'ver,': {' ': 1.0},
#  'r, k': {'i': 1.0},
#  ', ki': {'n': 1.0},
#  'brid': {'g': 1.0},
#  'ridg': {'e': 1.0},
#  'idge': {' ': 1.0},
#  'dge ': {'g': 1.0},
#  'ge g': {'a': 1.0},
#  ' gap': {'s': 1.0},
#  'gaps': {' ': 1.0},
#  'aps ': {'a': 1.0},
#  'ps a': {'n': 1.0},
#  'nd b': {'r': 1.0},
#  'd br': {'i': 1.0},
#  'brin': {'g': 1.0},
#  'ring': {' ': 0.5, 's': 0.5},
#  'ng p': {'e': 1.0},
#  'g pe': {'o': 1.0},
#  'le t': {'o': 1.0},
#  ' tog': {'e': 1.0},
#  'toge': {'t': 1.0},
#  'oget': {'h': 1.0},
#  'geth': {'e': 1.0},
#  'ethe': {'r': 1.0},
#  'her.': {' ': 1.0},
#  'er. ': {'i': 1.0},
#  'r. i': {'t': 1.0},
#  'it d': {'o': 1.0},
#  't do': {'e': 1.0},
#  ' doe': {'s': 1.0},
#  'does': {'n': 1.0},
#  'oesn': {"'": 1.0},
#  "esn'": {'t': 1.0},
#  "sn't": {' ': 1.0},
#  "n't ": {'m': 1.0},
#  "'t m": {'a': 1.0},
#  ' mat': {'t': 1.0},
#  'matt': {'e': 1.0},
#  'atte': {'r': 0.5, 'n': 0.5},
#  'er w': {'h': 0.5, 'i': 0.5},
#  'r wh': {'e': 0.5, 'a': 0.5},
#  'wher': {'e': 1.0},
#  're s': {'o': 0.3333333333333333,
#   'h': 0.3333333333333333,
#   'u': 0.3333333333333333},
#  'e so': {'m': 1.0},
#  'ne c': {'o': 0.5, 'a': 0.5},
#  'e co': {'m': 0.5, 'n': 0.5},
#  ' com': {'e': 0.2857142857142857,
#   'p': 0.14285714285714285,
#   'm': 0.5714285714285714},
#  'come': {'s': 0.3333333333333333, ' ': 0.6666666666666666},
#  'omes': {' ': 1.0},
#  'mes ': {'f': 0.5, 'o': 0.5},
#  'es f': {'r': 0.5, 'e': 0.5},
#  's fr': {'o': 1.0},
#  ' fro': {'m': 1.0},
#  'from': {' ': 1.0},
#  'rom ': {'o': 0.5, 'd': 0.5},
#  'om o': {'r': 1.0},
#  'm or': {' ': 1.0},
#  'or w': {'h': 1.0},
#  'at t': {'h': 1.0},
#  'they': {' ': 1.0},
#  'hey ': {'b': 0.6666666666666666, 'a': 0.3333333333333333},
#  'ey b': {'e': 1.0},
#  'y be': {'l': 0.3333333333333333,
#   'n': 0.3333333333333333,
#   'c': 0.3333333333333333},
#  ' bel': {'i': 0.5, 'o': 0.5},
#  'beli': {'e': 1.0},
#  'elie': {'v': 1.0},
#  'liev': {'e': 1.0},
#  'ieve': {' ': 1.0},
#  'eve ': {'i': 1.0},
#  've i': {'n': 1.0},
#  ' in;': {' ': 1.0},
#  'in; ': {'k': 1.0},
#  'n; k': {'i': 1.0},
#  '; ki': {'n': 1.0},
#  ' a u': {'n': 1.0},
#  'a un': {'i': 1.0},
#  ' uni': {'v': 1.0},
#  'univ': {'e': 1.0},
#  'nive': {'r': 1.0},
#  'iver': {'s': 1.0},
#  'vers': {'a': 0.5, 'e': 0.5},
#  'ersa': {'l': 1.0},
#  'rsal': {' ': 1.0},
#  'sal ': {'l': 1.0},
#  'al l': {'a': 1.0},
#  'l la': {'n': 1.0},
#  ' lan': {'g': 1.0},
#  'lang': {'u': 1.0},
#  'angu': {'a': 1.0},
#  'ngua': {'g': 1.0},
#  'guag': {'e': 1.0},
#  'uage': {' ': 1.0},
#  'age ': {'t': 1.0},
#  'ge t': {'h': 0.6666666666666666, 'o': 0.3333333333333333},
#  'at e': {'v': 0.3333333333333333,
#   'a': 0.3333333333333333,
#   'm': 0.3333333333333333},
#  't ev': {'e': 1.0},
#  ' eve': {'r': 1.0},
#  'ever': {'y': 1.0},
#  'very': {'o': 0.6666666666666666, ' ': 0.3333333333333333},
#  'eryo': {'n': 1.0},
#  'ryon': {'e': 1.0},
#  'yone': {' ': 0.5, '.': 0.5},
#  'e ca': {'n': 1.0},
#  'an u': {'n': 1.0},
#  'n un': {'d': 1.0},
#  'd an': {'d': 0.6666666666666666, 'x': 0.3333333333333333},
#  'ate.': {' ': 1.0},
#  'te. ': {'i': 1.0},
#  'e. i': {'t': 1.0},
#  ' a w': {'a': 0.5, 'h': 0.5},
#  'a wa': {'y': 1.0},
#  'way ': {'t': 1.0},
#  'ay t': {'o': 1.0},
#  'o bu': {'i': 1.0},
#  ' bui': {'l': 1.0},
#  'buil': {'d': 0.6666666666666666, 't': 0.3333333333333333},
#  'uild': {' ': 1.0},
#  'ild ': {'c': 0.5, 'b': 0.5},
#  'ld c': {'o': 1.0},
#  'd co': {'n': 0.5, 'm': 0.5},
#  'conn': {'e': 1.0},
#  'onne': {'c': 1.0},
#  'nnec': {'t': 1.0},
#  'nect': {'i': 0.6666666666666666, ',': 0.3333333333333333},
#  'ctio': {'n': 1.0},
#  'tion': {'s': 0.6, '.': 0.1, ' ': 0.2, ',': 0.1},
#  'ions': {' ': 0.6, 'h': 0.2, '.': 0.2},
#  'ons ': {'a': 0.6666666666666666, 'w': 0.3333333333333333},
#  'ns a': {'n': 1.0},
#  'd fo': {'s': 0.25, 'r': 0.75},
#  ' fos': {'t': 1.0},
#  'fost': {'e': 1.0},
#  'oste': {'r': 1.0},
#  'ster': {' ': 0.5, 's': 0.5},
#  'er u': {'n': 1.0},
#  'r un': {'d': 1.0},
#  'andi': {'n': 1.0},
#  'ndin': {'g': 1.0},
#  'g am': {'o': 1.0},
#  ' amo': {'n': 1.0},
#  'amon': {'g': 1.0},
#  'mong': {' ': 1.0},
#  'ong ': {'p': 1.0},
#  'le f': {'r': 1.0},
#  'e fr': {'o': 1.0},
#  'om d': {'i': 1.0},
#  'm di': {'v': 1.0},
#  ' div': {'e': 1.0},
#  'dive': {'r': 1.0},
#  'erse': {' ': 1.0},
#  'rse ': {'b': 1.0},
#  'se b': {'a': 1.0},
#  'e ba': {'c': 1.0},
#  ' bac': {'k': 1.0},
#  'back': {'g': 1.0},
#  'ackg': {'r': 1.0},
#  'ckgr': {'o': 1.0},
#  'kgro': {'u': 1.0},
#  'grou': {'n': 1.0},
#  'roun': {'d': 1.0},
#  'ound': {'s': 0.25, 'a': 0.25, ' ': 0.5},
#  'unds': {'.': 1.0},
#  'nds.': {'\n': 1.0},
#  'ds.\n': {'\n': 1.0},
#  's.\n\n': {'t': 0.5, 'n': 0.5},
#  '.\n\nt': {'e': 1.0},
#  '\n\nte': {'a': 1.0},
#  '\ntea': {'c': 1.0},
#  'teac': {'h': 1.0},
#  'each': {'i': 0.3333333333333333, ' ': 0.6666666666666666},
#  'achi': {'n': 1.0},
#  'chin': {'g': 1.0},
#  'ng k': {'i': 1.0},
#  'g ki': {'n': 1.0},
#  's al': {'s': 0.6666666666666666, 'w': 0.3333333333333333},
#  ' als': {'o': 1.0},
#  'also': {' ': 1.0},
#  'lso ': {'c': 0.25, 'h': 0.25, 'b': 0.25, 'r': 0.25},
#  'so c': {'r': 1.0},
#  'o cr': {'u': 1.0},
#  ' cru': {'c': 1.0},
#  'cruc': {'i': 1.0},
#  'ruci': {'a': 1.0},
#  'ucia': {'l': 1.0},
#  'cial': {',': 0.3333333333333333,
#   'l': 0.3333333333333333,
#   ' ': 0.3333333333333333},
#  'ial,': {' ': 1.0},
#  'al, ': {'e': 0.5, 'c': 0.5},
#  'l, e': {'s': 1.0},
#  ', es': {'p': 1.0},
#  ' esp': {'e': 1.0},
#  'peci': {'a': 1.0},
#  'iall': {'y': 1.0},
#  'ally': {' ': 1.0},
#  'lly ': {'t': 0.3333333333333333,
#   'h': 0.3333333333333333,
#   'a': 0.3333333333333333},
#  'o ou': {'r': 1.0},
#  'ur y': {'o': 1.0},
#  'r yo': {'u': 1.0},
#  'youn': {'g': 1.0},
#  'oung': {'e': 1.0},
#  'unge': {'r': 1.0},
#  'nger': {' ': 1.0},
#  'ger ': {'g': 0.5, 'a': 0.5},
#  'er g': {'e': 1.0},
#  'r ge': {'n': 1.0},
#  'gene': {'r': 1.0},
#  'ener': {'a': 1.0},
#  'nera': {'t': 0.5, 'l': 0.5},
#  'rati': {'o': 1.0},
#  'atio': {'n': 1.0},
#  'ion.': {' ': 1.0},
#  'on. ': {'w': 1.0},
#  'n. w': {'h': 1.0},
#  'we t': {'e': 1.0},
#  'e te': {'a': 1.0},
#  ' tea': {'c': 0.5, 'm': 0.5},
#  'ach ': {'o': 1.0},
#  'ch o': {'u': 0.5, 't': 0.5},
#  'h ou': {'r': 1.0},
#  'ur c': {'h': 0.3333333333333333, 'o': 0.6666666666666666},
#  'r ch': {'i': 1.0},
#  ' chi': {'l': 1.0},
#  'chil': {'d': 1.0},
#  'hild': {'r': 1.0},
#  'ildr': {'e': 1.0},
#  'ldre': {'n': 1.0},
#  'dren': {' ': 1.0},
#  'ren ': {'t': 1.0},
#  'en t': {'o': 1.0},
#  'n to': {' ': 1.0},
#  'o be': {' ': 0.6666666666666666, 'e': 0.3333333333333333},
#  'be k': {'i': 1.0},
#  'ind,': {' ': 1.0},
#  'nd, ': {'w': 1.0},
#  'd, w': {'e': 1.0},
#  ' sha': {'p': 0.5, 'r': 0.5},
#  'shap': {'i': 1.0},
#  'hapi': {'n': 1.0},
#  'apin': {'g': 1.0},
#  'em i': {'n': 1.0},
#  'm in': {'t': 1.0},
#  ' int': {'o': 0.5, 'e': 0.5},
#  'into': {' ': 1.0},
#  'nto ': {'c': 1.0},
#  'to c': {'o': 1.0},
#  'o co': {'m': 1.0},
#  'comp': {'a': 1.0},
#  'ompa': {'s': 1.0},
#  'mpas': {'s': 1.0},
#  'pass': {'i': 1.0},
#  'assi': {'o': 1.0},
#  'ssio': {'n': 1.0},
#  'sion': {'a': 0.25, ',': 0.5, ' ': 0.25},
#  'iona': {'t': 1.0},
#  'onat': {'e': 1.0},
#  'nate': {' ': 1.0},
#  'nd e': {'m': 1.0},
#  'd em': {'p': 1.0},
#  ' emp': {'a': 0.8333333333333334, 'l': 0.16666666666666666},
#  'empa': {'t': 1.0},
#  'mpat': {'h': 1.0},
#  'path': {'e': 0.4, 'y': 0.6},
#  'thet': {'i': 1.0},
#  'heti': {'c': 1.0},
#  'etic': {' ': 1.0},
#  'tic ': {'i': 1.0},
#  'ic i': {'n': 1.0},
#  'c in': {'d': 1.0},
#  ' ind': {'i': 1.0},
#  'indi': {'v': 1.0},
#  'ndiv': {'i': 1.0},
#  'divi': {'d': 1.0},
#  'ivid': {'u': 1.0},
#  'vidu': {'a': 1.0},
#  'idua': {'l': 1.0},
#  'dual': {'s': 1.0},
#  'uals': {' ': 1.0},
#  'als ': {'w': 0.3333333333333333,
#   'b': 0.3333333333333333,
#   'a': 0.3333333333333333},
#  'ls w': {'h': 1.0},
#  ' who': {' ': 0.6666666666666666, 'l': 0.3333333333333333},
#  'who ': {'w': 0.5, 'e': 0.5},
#  'ho w': {'i': 1.0},
#  'o wi': {'l': 1.0},
#  ' wil': {'l': 1.0},
#  ...}

# %% [markdown]
# # generate text at text time

# %%
import numpy as np




def sample_next(smp,T,k):
    smp = smp[-k:]
    if T.get(smp) == None:
        return " "
    
    possible_character = list(T[smp].keys())
    possible_value = list(T[smp].values())
    
    return np.random.choice(possible_character , p=possible_value)

# %%
sample_next('kindn',model,4)
# Out:
# 'e'

# %% [markdown]
# # Generating continuous text

# %%
def generatetext(starting_text, k =4 , maxlength =1000):
    
    sentence  = starting_text
    smp = starting_text[-k:]
    
    for ix in range(maxlength):
        next_predic = sample_next(smp , model ,k)
        
        sentence += next_predic
        smp = sentence[-k:]
        
    return sentence

# %%
tex = generatetext("kindness", 4, 200)

print(tex)
# Out:
# kindness, we can lead to do society. in that can be as giving neighborhoods stress is a way to do someone a big difference in ourselves is closely linked to othermore, act the world a better resilient. when c
